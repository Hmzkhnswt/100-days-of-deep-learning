# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.layers import Dense
from keras.models import Sequential
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Using simple data fro keras to show early stopping

# %%
X,y = make_circles(n_samples=300, noise=0.05, random_state=41)

# %%
df = pd.DataFrame({'Feature1': X[:, 0], 'Feature2': X[:, 1], 'Label': y})
df
# Out:
#      Feature1  Feature2  Label
# 0   -0.351760  0.753028      1
# 1   -0.541101  0.842153      0
# 2    0.523519 -0.788427      0
# 3   -0.062863 -0.783611      1
# 4    0.736582  0.030975      1
# ..        ...       ...    ...
# 295 -0.658842 -0.364806      1
# 296  0.650867 -0.559054      1
# 297 -0.831334 -0.526986      0
# 298 -0.571565 -0.588195      1
# 299 -0.975139 -0.237204      0
#
# [300 rows x 3 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y, test_size=0.2, random_state=41)

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_dim = 2))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 24
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 2)                 10
#
#  dense_3 (Dense)             (None, 1)                 3
#
# ...
# Total params: 73 (292.00 Byte)
# Trainable params: 73 (292.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# #### Suitable Epochs will be deide by this earlystopping fuction in keras

# %%
from keras.callbacks import EarlyStopping
callback = EarlyStopping(
    monitor= 'accuracy',
    min_delta= 0.0001,
    mode= 'auto',
    patience=10,
    verbose=True
)

# %% [markdown]
# #### In the output of this we see we run for 500 but stops after 144 beacause of the no significant change in accurcy

# %%
model.fit(xtrain,ytrain, epochs=500, callbacks=callback)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.5125
# Epoch 2/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6891 - accuracy: 0.5125
# Epoch 3/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6889 - accuracy: 0.5208
# Epoch 4/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.5208
# Epoch 5/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6883 - accuracy: 0.5250
# Epoch 6/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.5417
# Epoch 7/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.5417
# Epoch 8/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5375
# Epoch 9/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6870 - accuracy: 0.5458
# Epoch 10/500
# ...
