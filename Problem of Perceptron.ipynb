# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['output']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['output']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['output']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
import seaborn as sns

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(data=and_data, x=and_data['input1'], y=and_data['input2'],hue=and_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(data=or_data, x=or_data['input1'], y=or_data['input2'],hue=or_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
plt.figure(figsize=(9,5))
sns.scatterplot(data=xor_data, x=xor_data['input1'], y=xor_data['input2'],hue=xor_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
x = np.linspace(-2,2,5)
y = -x+1

# %%
plt.plot(x,y)
sns.scatterplot(data=and_data, x=and_data['input1'], y=and_data['input2'],hue=and_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
plt.plot(x,y)
sns.scatterplot(data=or_data, x=or_data['input1'], y=or_data['input2'],hue=or_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
plt.plot(x,y)
sns.scatterplot(data=xor_data, x=xor_data['input1'], y=xor_data['input2'],hue=xor_data['output'])
# Out:
# <Axes: xlabel='input1', ylabel='input2'>
